# %% [markdown]
# **Import Library**

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Membaca citra, citra yang digunakan adalah citra photo yang memiliki noise berupa bintik-bintik. Unduh dataset pada tautan berikut**

# %%
citra = cv2.imread("photo.jpeg")
citra = cv2.cvtColor(citra, cv2.COLOR_RGB2GRAY)

# %% [markdown]
# **Menyalin citra ke variabel khusus dan melihat atribut citra berupa jumlah baris dan kolom**

# %%
copyCitra1 = citra.copy().astype(float)

m1,n1 = copyCitra1.shape
output1 =np.empty([m1, n1])

print('Shape copy citra 1 : ', copyCitra1.shape)
print('Shape output citra 1 : ', copyCitra1.shape)

print('m1 : ', m1)
print('n1 : ', n1)
print()
# Out:
# Shape copy citra 1 :  (1280, 960)
# Shape output citra 1 :  (1280, 960)
# m1 :  1280
# n1 :  960

# %% [markdown]
# **Membuat filter mean**

# %%
for baris in range(0, m1-1):
  for kolom in range(0, n1-1):
    a1 = baris
    b1 = kolom
    jumlah = copyCitra1[a1-1, b1-1] + copyCitra1[a1-1, b1] + copyCitra1[a1-1, b1-1] +\
    copyCitra1[a1, b1-1] + copyCitra1[a1, b1] +copyCitra1[a1, b1+1] +\
    copyCitra1[a1+1, b1-1] + copyCitra1[a1+1, b1] + copyCitra1[a1+1, b1+1]
    output1[a1, b1] = (1/9 * jumlah)

# %%
fig, axis = plt.subplots(1,2, figsize=(10,10))
ax = axis.ravel()

ax[0].imshow(citra, cmap = 'gray')
ax[0].set_title("input citra 1")

ax[1].imshow(citra, cmap = 'gray')
ax[1].set_title("output citra 1")
# Out:
# Text(0.5, 1.0, 'output citra 1')

# %% [markdown]
# **Membuat filter median**

# %%
citra2 = cv2.imread("photo.jpeg")
img_median = citra2.copy()
img_median = cv2.cvtColor(img_median, cv2.COLOR_BGR2RGB)
img_median_after = cv2.medianBlur(img_median, 5)

plt.figure(figsize=(11,6))
plt.subplot(121), plt.imshow(img_median), plt.title('gambar asli')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(img_median_after), plt.title('gambar filter')
plt.xticks([]), plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
citra1 = cv2.imread("photo.jpeg")
citra1 = cv2.cvtColor(citra1, cv2.COLOR_RGB2GRAY)
copyCitra1 = citra1.copy().astype(float)

m1, n1 =  copyCitra1.shape
output1 = citra1.copy().astype(float)

for baris in range(0, m1-1):
  for kolom in range(0, n1-1):
    a1 = baris
    b1 = kolom
    arr = np.array ([copyCitra1[a1-1, b1-1]]) + copyCitra1[a1-1, b1] + copyCitra1[a1-1, b1-1] +\
    copyCitra1[a1, b1-1] + copyCitra1[a1, b1] +copyCitra1[a1, b1+1] +\
    copyCitra1[a1+1, b1-1] + copyCitra1[a1+1, b1] + copyCitra1[a1+1, b1+1]

    minPiksel = np.amin(arr)
    maxPiksel = np.amax(arr)

    if copyCitra1[baris,kolom]<minPiksel:
      output1[baris,kolom] = minPiksel
    else:
      if copyCitra1[baris,kolom]>maxPiksel:
         output1[baris,kolom] = maxPiksel
      else:
        output1[baris,kolom] = copyCitra1[baris,kolom]

# %%
fig, axis = plt.subplots(1,2, figsize=(10,10))
ax = axis.ravel()

ax[0].imshow(citra, cmap = 'gray')
ax[0].set_title("Original Image ")

ax[1].imshow(citra, cmap = 'gray')
ax[1].set_title("Citra hasil filter rata-rata ")
# Out:
# Text(0.5, 1.0, 'Citra hasil filter rata-rata ')

# %%
plt.figure(figsize=(11,6))
plt.subplot(121), plt.imshow(img_median), plt.title('citra asli')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(img_median_after), plt.title('after filter median')
plt.xticks([]), plt.yticks([])
plt.show

fig, axis = plt.subplots(1,2, figsize=(10,10))
ax = axis.ravel()

ax[0].imshow(citra, cmap = 'gray')
ax[0].set_title("Original Image ")

ax[1].imshow(citra, cmap = 'gray')
ax[1].set_title("mean filtered image ")
# Out:
# Text(0.5, 1.0, 'mean filtered image ')
